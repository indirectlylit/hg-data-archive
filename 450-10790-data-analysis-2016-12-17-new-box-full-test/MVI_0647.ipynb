# %% [markdown]
# # MVI_0647
#
# **[Video Link](https://drive.google.com/file/d/0B2LG2DoWMi1VdmliZEZMT0ZqWTQ/)**
#
# | MVI_0647 Events     | Time |
# |-----------|------|
# | Ding | (none) |
# | Shut-down | 1:47 |
# | Back on | 2:00 |
# | Shut-down | 2:50 |
# | Back on | 3:02 |
# | End | 8:10 |

# %%
# %run chart_data_v1.py
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
mpl.rcParams['figure.figsize'] = [CHART_WIDTH, 4]
mpl.rcParams['font.size'] = 12
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'medium'
mpl.rcParams['axes.grid'] = True

# %%
all_data = pd.read_pickle('all_data.pkl')

# %%
data = load_data(all_data, "2016-12-17 20:06:09.906000", (1, 47), (8, 10))

# %% [markdown]
# ## System State

# %%
plot_system_state(data)

# %%
plot_voltage(data)

# %% [markdown]
# ## Power

# %%
plot_cap_power(data)

# %% [markdown]
# ## Energy

# %%
plot_total_energy(data)
