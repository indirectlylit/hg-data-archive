# %% [markdown]
# # MVI_0649
#
# **[Video Link](https://drive.google.com/file/d/0B2LG2DoWMi1VZm1mejROSVlCYjA/)**
#
#
# | MVI_0647 Events     | Time |
# |-----------|------|
# | Ding 1 | 3:26 |
# | Ding 2 | 3:30 |
# | Shut-down | 6:23 |
# | End | 7:15
#
#
#
# * Camera timestamp: 4:18 PM
# * Length: 7:15

# %%
# %run chart_data_v1.py
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
mpl.rcParams['figure.figsize'] = [CHART_WIDTH, 4]
mpl.rcParams['font.size'] = 12
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'medium'
mpl.rcParams['axes.grid'] = True

# %%
all_data = pd.read_pickle('all_data.pkl')

# %%
all_data[all_data.chan == 'logger.state.clap'].dropna(how='all', axis=1)
# Out:
#                                       chan
# time
# 2016-12-17 19:30:17.335  logger.state.clap
# 2016-12-17 19:30:21.233  logger.state.clap
# 2016-12-17 20:23:25.529  logger.state.clap
# 2016-12-17 20:23:26.573  logger.state.clap
# 2016-12-17 20:23:33.115  logger.state.clap
# 2016-12-17 20:23:38.369  logger.state.clap

# %%
all_data.tail()
# Out:
#                             address  btn    c_1    c_2    c_3    c_4  c_bits  \
# time
# 2016-12-17 20:26:42.196  10.0.0.118  NaN  0.028  0.028  0.028  0.028     NaN
# 2016-12-17 20:26:42.198  10.0.0.129  NaN  0.028  0.028  0.028  0.028     NaN
# 2016-12-17 20:26:42.200  10.0.0.149  NaN    NaN    NaN    NaN    NaN     0.0
# 2016-12-17 20:26:42.202  10.0.0.126  NaN    NaN    NaN    NaN    NaN     0.0
# 2016-12-17 20:26:42.204  10.0.0.131  NaN    NaN    NaN    NaN    NaN     0.0
#
#                          c_in  c_out  c_out_fwd  c_out_rev  c_shunt  c_t1  \
# time
# 2016-12-17 20:26:42.196   NaN    NaN        NaN        NaN      NaN   NaN
# 2016-12-17 20:26:42.198   NaN    NaN        NaN        NaN      NaN   NaN
# 2016-12-17 20:26:42.200   NaN  0.066        NaN        NaN      NaN   NaN
# 2016-12-17 20:26:42.202   NaN  0.066        NaN        NaN      NaN   NaN
# 2016-12-17 20:26:42.204   NaN  0.066        NaN        NaN      NaN   NaN
#
# ...

# %%
data = load_data(all_data, "2016-12-17 20:18:00", (0, 0), (30, 51))
# Out:
# START 2016-12-17 20:18:00

# %% [markdown]
# ## System State

# %%
plot_system_state(data)

# %%
plot_voltage(data)

# %% [markdown]
# ## Power

# %%
plot_cap_power(data)

# %% [markdown]
# ## Energy

# %%
plot_total_energy(data)
