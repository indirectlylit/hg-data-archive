# %% [markdown]
# # MVI_0648
#
# **[Video Link](https://drive.google.com/file/d/0B2LG2DoWMi1VWVRHbTRnTktYNXM/)**
#
# * Camera timestamp: 4:11 PM
# * Lowering music/bike switch 5:05-6:55
# * Length: 7:31

# %%
# %run chart_data_v1.py
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
mpl.rcParams['figure.figsize'] = [CHART_WIDTH, 4]
mpl.rcParams['font.size'] = 12
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'medium'
mpl.rcParams['axes.grid'] = True

# %%
all_data = pd.read_pickle('all_data.pkl')

# %%
data = load_data(all_data, "2016-12-17 20:11:00", "00:07:31")
# Out:
# START 2016-12-17 20:11:00
# END 2016-12-17 20:18:31

# %% [markdown]
# ## System State

# %%
plot_system_state(data)

# %%
plot_voltage(data)

# %% [markdown]
# ## Power

# %%
plot_cap_power(data)

# %% [markdown]
# ## Energy

# %%
plot_total_energy(data)
